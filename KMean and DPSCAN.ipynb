# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans, DBSCAN
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\PC\Downloads\dataset6.csv',header=None,names=['X1','X2'])
#df=df.rename(columns={df.columns[0]:'x',df.rename(columns={df.columns[0]:'y'})

# %%
df.head()
# Out:
#          X1        X2
# 0  1.578527  1.408111
# 1  1.748206  0.441915
# 2  1.523151  0.681521
# 3  1.318949  0.362971
# 4  0.977164 -0.373589

# %%
sns.scatterplot(data=df, x='X1', y='X2')

# Display the plot
plt.show()

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
# K-means clustering
kmeans = KMeans(n_clusters=3)
kmeans_labels = kmeans.fit_predict(df)

# DBSCAN clustering
dbscan = DBSCAN(eps=0.3, min_samples=9)
dbscan_labels = dbscan.fit_predict(df)

# Plot the data and cluster labels
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].scatter(df.iloc[:, 0], df.iloc[:, 1], c=kmeans_labels)
axs[0].set_title('K-means Clustering')

axs[1].scatter(df.iloc[:, 0], df.iloc[:, 1], c=dbscan_labels)
axs[1].set_title('DBSCAN Clustering')

plt.show()

# %%
df2 = pd.read_csv(r'C:\Users\PC\Downloads\Datasets\dataset7.csv',header=None,names=['n1','n2'])
df2.head()
# Out:
#          n1        n2
# 0  1.332228  0.178299
# 1  1.256056  0.146765
# 2  1.477661  0.155054
# 3  1.384840  0.022054
# 4  1.526956  0.267920

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df2)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
# K-means 
kmeans = KMeans(n_clusters=3)
kmeans_labels = kmeans.fit_predict(df2)

# DBSCAN 
dbscan = DBSCAN(eps=0.4, min_samples=7)
dbscan_labels = dbscan.fit_predict(df2)


fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].scatter(df.iloc[:, 0], df2.iloc[:, 1], c=kmeans_labels)
axs[0].set_title('K-means Clustering')

axs[1].scatter(df.iloc[:, 0], df2.iloc[:, 1], c=dbscan_labels)
axs[1].set_title('DBSCAN Clustering')

plt.show()

# %%
df3 = pd.read_csv(r'C:\Users\PC\Downloads\Datasets\dataset8.csv')
df3.head()
# Out:
#           x         y
# 0  2.852449 -0.324568
# 1  2.346342 -0.729224
# 2  2.229033 -0.599340
# 3  2.458669 -0.385467
# 4  2.844177 -0.196813

# %%
sns.scatterplot(data=df3, x='x', y='y')

# Display the plot
plt.show()

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df3)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
# K-means clustering
kmeans = KMeans(n_clusters=4)
kmeans_labels = kmeans.fit_predict(df3)

# DBSCAN clustering
dbscan = DBSCAN(eps=0.3, min_samples=10)
dbscan_labels = dbscan.fit_predict(df3)

# Plot the data and cluster labels
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].scatter(df3.iloc[:, 0], df3.iloc[:, 1], c=kmeans_labels)
axs[0].set_title('K-means Clustering')

axs[1].scatter(df3.iloc[:, 0], df3.iloc[:, 1], c=dbscan_labels)
axs[1].set_title('DBSCAN Clustering')

plt.show()

# %%
df4 = pd.read_csv(r'C:\Users\PC\Downloads\Datasets\dataset9.csv')
df4.head()
# Out:
#           x         y
# 0  0.712520  0.653491
# 1  0.910914  0.068242
# 2  0.750752  0.526512
# 3  0.666605  0.584747
# 4  0.403062  0.956459

# %%
sns.scatterplot(data=df4, x='x', y='y')

# Display the plot
plt.show()

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df4)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
# K-means clustering
kmeans = KMeans(n_clusters=3)
kmeans_labels = kmeans.fit_predict(df4)

# DBSCAN clustering
dbscan = DBSCAN(eps=0.3, min_samples=9)
dbscan_labels = dbscan.fit_predict(df4)

# Plot the data and cluster labels
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].scatter(df4.iloc[:, 0], df4.iloc[:, 1], c=kmeans_labels)
axs[0].set_title('K-means Clustering')

axs[1].scatter(df4.iloc[:, 0], df4.iloc[:, 1], c=dbscan_labels)
axs[1].set_title('DBSCAN Clustering')

plt.show()

# %%
df5=pd.read_csv(r'C:\Users\PC\Downloads\Datasets\dataset5.csv',names=['x','y'],header=None)
df5.head()
# Out:
#           x         y
# 0  1.206087  1.847686
# 1  0.351919  0.245691
# 2  1.201688  0.630774
# 3  0.733710  1.364328
# 4  1.150745  0.724892

# %%
sns.scatterplot(data=df5,x='x',y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df5)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmeans=KMeans(n_clusters=3)
kmeans_labels=kmeans.fit_predict(df5)

dbscan=DBSCAN(eps=0.3,min_samples=8)
dbscan_labels=dbscan.fit_predict(df5)


fig , axis = plt.subplots(1 , 2 , figsize=(10 , 5))

axis[0].scatter(df5.iloc[:,0],df5.iloc[:,1],c=kmeans_labels)
axis[0].set_title('K-means Clustering')

axis[1].scatter(df5.iloc[:,0],df5.iloc[:,1],c=dbscan_labels)
axis[1].set_title('DBSCAN Clustering')


plt.show()
